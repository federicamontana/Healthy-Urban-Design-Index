# %%
"""
Created on 30/12/2024

@author: federica montana

This file is used to calculate the indicators both at 250m resoltuion and city level for the 916 cities and 1 greater city (London) - 917 cities in total

"""
# Import packages
import pandas as pd
import os
os.environ['USE_PYGEOS'] = '0'
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import seaborn as sns
from utility import clusters, rescaling_dwellings
from libpysal import weights

# %% [markdown]
# ## Urban design

# %% [markdown]
# ### Optimal dwelling density

# %%
"""
Calculate the optimal dwelling density for each city at 250m resolution and city level
Columns of data:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Value of dwellings per hectare at 250m resolution.
- person_per_house: Number of persons per house.
"""
df = pd.read_csv('DATA/data/df_dwellings.csv')
df_popt = pd.read_csv('DATA\\data\\grid_pop.csv')
for cluster in clusters:
    # Read data
    df_odd = df[df.cluster==cluster]      

    # Grids      
    df1 = rescaling_dwellings(df_odd,'val_grid','rescaled_grid', target_val=6)
    df1.to_csv(f'DATA\\new_data\\{cluster}\\grid\\Urban Design_Optimal dwelling density.csv',index = False)

    # City
    df2 = df_odd.copy()
    df2['pop_city'] = df2.groupby('urau_code')['pop_final'].transform('sum')
    df2['dwelling_city'] = pd.to_numeric(df2['pop_city']/df2['person_per_house']) #number of housing 
    df_pop = df_popt[df_popt.cluster==cluster]
    df_pop['area'] = df_pop.groupby('urau_code')['urau_code'].transform('size') * 6.25 #area in ha
    df2 = pd.merge(df2, df_pop[['urau_code','gid','area']], on=['urau_code','gid'], how='left')
    df2['dwelling_city_ha'] = df2['dwelling_city'] / df2['area']
    df2.rename(columns={'dwelling_city_ha': 'val_city'}, inplace=True)
    #Take the city just once
    df2 = df2.drop_duplicates(subset=['urau_code'])

    #Divide the two dataset to apply differente rescale function
    df3 = rescaling_dwellings(df2,'val_city','rescaled_city', target_val=6)
    
    # Save data
    df3.to_csv(f'DATA\\new_data\\{cluster}\\city\\Urban Design_Optimal dwelling density.csv',index = False)
# Out:
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\3745889508.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop['area'] = df_pop.groupby('urau_code')['urau_code'].transform('size') * 6.25 #area in ha
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noprov.loc[noprov['val_log'] < np.log(45), new_col] = np.interp(
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prov[new_col] = target_val + (peak_value - target_val) * scaling_factor
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\3745889508.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop['area'] = df_pop.groupby('urau_code')['urau_code'].transform('size') * 6.25 #area in ha
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noprov.loc[noprov['val_log'] < np.log(45), new_col] = np.interp(
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prov[new_col] = target_val + (peak_value - target_val) * scaling_factor
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\3745889508.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop['area'] = df_pop.groupby('urau_code')['urau_code'].transform('size') * 6.25 #area in ha
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noprov.loc[noprov['val_log'] < np.log(45), new_col] = np.interp(
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prov[new_col] = target_val + (peak_value - target_val) * scaling_factor
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\3745889508.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop['area'] = df_pop.groupby('urau_code')['urau_code'].transform('size') * 6.25 #area in ha
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noprov.loc[noprov['val_log'] < np.log(45), new_col] = np.interp(
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prov[new_col] = target_val + (peak_value - target_val) * scaling_factor
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\3745889508.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop['area'] = df_pop.groupby('urau_code')['urau_code'].transform('size') * 6.25 #area in ha
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   noprov.loc[noprov['val_log'] < np.log(45), new_col] = np.interp(
# c:\Users\fmontana\Desktop\HUDI\Healthy-Urban-Design-Index\utility.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prov[new_col] = target_val + (peak_value - target_val) * scaling_factor

# %% [markdown]
# ### Compactness

# %%
"""
Calculate Compactness for each city at city level using the gdftot which is the geodataframe having the population and the geometry of each grids
Columns of data:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
"""
# --------------------------------------------------
# 1. Load your grid GeoDataFrame (250x250 m cells)

gdftot = gpd.read_file(f'DATA/data/gdf_pop.geojson').sort_values(by=['gid'], ascending=True)

# --------------------------------------------------
# Just ensure 'gdf' is in a projected CRS with meter units 
# (so areas make sense).
def classify_urban_clusters(gdf):
    # Thresholds based on 1,500/km² and 300/km²
    # for a 0.0625 km² cell (250m × 250m).
    hd_threshold = 93.75   # (1,500 inh./km² × 0.0625 km²)
    md_threshold = 18.75   # (300   inh./km² × 0.0625 km²)

    # Minimum total population for the entire cluster
    hd_min_pop = 50000  # Urban centre
    md_min_pop = 5000   # Urban cluster

    # --------------------------------------------------
    # 2. Identify Urban Centre Cells
    #    (High-Density: pop >= hd_threshold)
    # --------------------------------------------------
    gdf_hd = gdf[gdf['pop_final'] >= hd_threshold].copy()

    # Compute Rook contiguity only for these high-density cells
    if len(gdf_hd) > 0:
        w_rook = weights.contiguity.Rook.from_dataframe(gdf_hd)
        # Continue adjacency logic
        w_rook = weights.contiguity.Rook.from_dataframe(gdf_hd)
        rook_components = w_rook.component_labels
        gdf_hd['rook_comp'] = rook_components

        # Sum population in each rook-based cluster
        pop_by_rook_comp = gdf_hd.groupby('rook_comp')['pop_final'].sum()

        # Which clusters meet the total pop >= 50,000 ?
        urban_centre_components = pop_by_rook_comp[pop_by_rook_comp >= hd_min_pop].index
        # Mark those cells as "Urban Center"
        gdf_hd['classification'] = np.where(
            gdf_hd['rook_comp'].isin(urban_centre_components),
            'Urban Center',
            'Exclude'  # high-density cell not reaching 50k in total cluster
        )
    
    else:
        # No cells pass the threshold
        # Create empty placeholders or skip classification
        gdf_hd['rook_comp'] = []
        gdf_hd['classification'] = []


    # Merge classification back into main gdf
    gdf = gdf.merge(
        gdf_hd[['rook_comp', 'classification']], 
        left_index=True, 
        right_index=True, 
        how='left', 
        suffixes=('', '_hd')
    )

    # Explanation of the merge:
    #  - Some cells in gdf won’t be in gdf_hd if their pop < hd_threshold => classification will be NaN there.
    #  - Cells that belong to a cluster with total pop < 50k => classification = 'Exclude' (they didn’t make it to Urban Center).
    #  - Cells that made it => classification = 'Urban Center'.

    # --------------------------------------------------
    # 3. Identify Urban Cluster Cells (Moderate-Density)
    #    among cells NOT "Urban Center"
    # --------------------------------------------------
    # Filter out:
    #   - Cells already "Urban Center"
    #   - Cells below moderate threshold
    mask_md = (
        (gdf['classification'] != 'Urban Center') &
        (gdf['pop_final'] >= md_threshold)
    )
    gdf_md = gdf[mask_md].copy()

    if len(gdf_md) > 0:
        # Only do adjacency if there's something to analyze
        w_queen = weights.contiguity.Queen.from_dataframe(gdf_md)
        queen_components = w_queen.component_labels
        gdf_md['queen_comp'] = queen_components

        # Sum population in each queen-based cluster
        pop_by_queen_comp = gdf_md.groupby('queen_comp')['pop_final'].sum()

        # Which clusters meet total pop >= md_min_pop ?
        urban_cluster_components = pop_by_queen_comp[pop_by_queen_comp >= md_min_pop].index

        gdf_md['classification_md'] = np.where(
            gdf_md['queen_comp'].isin(urban_cluster_components),
            'Urban Cluster',
            'Exclude'
        )
    else: # cities without urban center
        # If empty, we can create empty columns or do nothing
        gdf_md['queen_comp'] = []
        gdf_md['classification_md'] = []

    # Merge back into the main gdf
    gdf = gdf.merge(
        gdf_md[['queen_comp', 'classification_md']],
        left_index=True,
        right_index=True,
        how='left',
        suffixes=('', '_md')
    )

    # --------------------------------------------------
    # 4. Final classification
    # --------------------------------------------------
    def final_classification(row):
        # Priority 1: Urban Center
        if row['classification'] == 'Urban Center':
            return 'Urban Center'
        
        # Priority 2: Urban Cluster
        elif row['classification_md'] == 'Urban Cluster':
            return 'Urban Cluster'
        
        # Otherwise, Rural
        else:
            return 'Rural'

    gdf['final_class'] = gdf.apply(final_classification, axis=1)
    
    # Compute the sprawl
    tot_pop = gdf.pop_final.sum()
    ucluster_pop = gdf[gdf.final_class == 'Urban Cluster'].pop_final.sum()/tot_pop
    ucenter_pop = gdf[gdf.final_class == 'Urban Center'].pop_final.sum()/tot_pop
    ruralcluster_pop = gdf[gdf.final_class == 'Rural'].pop_final.sum()/tot_pop

    gdf['sprawl'] = ((ruralcluster_pop + ucluster_pop - ucenter_pop) + 1 )*50
    # Compactness
    gdf['val_city'] = 100-gdf['sprawl'] 
    # Scale to have values [0-10]
    gdf['val_city'] = gdf['val_city'].round(0).astype(int)
    return gdf

# Suppose gdftot is your complete GeoDataFrame with many cities,
# having columns: 'urau_code', 'pop_final', geometry, etc.
from utility import clusters
for cluster in clusters:
    gdf2 = gdftot[gdftot.cluster == cluster]
    classified_all = gdf2.groupby('urau_code', group_keys=False).apply(
        classify_urban_clusters
    )
    classified_all = classified_all.drop_duplicates(subset='urau_code')
    classified_all = classified_all.copy()
    # Rescaled values
    classified_all['rescaled_city'] = classified_all['val_city']/10
    classified_all = classified_all[['gid','urau_code','urau_name', 'pop_final', 'val_city', 'rescaled_city','cluster']]
    classified_all.to_csv(f'DATA/new_data\\{cluster}\\city\\Urban Design_Compactness.csv', index=False)
# Out:
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 42 disconnected components.
#  There are 19 islands with ids: 10, 773, 992, 1225, 1273, 1415, 1983, 2429, 2481, 2635, 2664, 2811, 2877, 2963, 2990, 3315, 3330, 3339, 3477.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 119 disconnected components.
#  There are 68 islands with ids: 5, 20, 24, 25, 26, 27, 29, 32, 33, 35, 38, 40, 41, 42, 43, 45, 46, 47, 60, 61, 67, 68, 76, 77, 78, 81, 86, 87, 90, 91, 111, 123, 124, 125, 126, 128, 131, 140, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 155, 162, 167, 169, 170, 181, 186, 200, 201, 214, 234, 242, 247, 250, 262, 276, 285, 299.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 88 disconnected components.
#  There are 44 islands with ids: 0, 106, 122, 128, 296, 297, 320, 324, 373, 374, 430, 484, 544, 614, 621, 651, 672, 704, 762, 861, 903, 940, 1096, 1097, 1149, 1164, 1410, 1411, 1485, 1486, 2212, 2980, 3675, 5400, 5773, 5832, 6411, 7583, 7770, 7790, 7796, 7807, 7832, 7848.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 214 disconnected components.
#  There are 110 islands with ids: 0, 7, 93, 94, 122, 146, 155, 171, 192, 205, 206, 252, 261, 272, 284, 349, 399, 457, 489, 529, 546, 570, 571, 600, 609, 615, 628, 651, 654, 659, 663, 706, 715, 740, 748, 754, 756, 758, 761, 763, 773, 787, 788, 799, 804, 808, 812, 816, 817, 818, 820, 824, 826, 828, 830, 831, 834, 838, 840, 843, 857, 865, 878, 879, 901, 913, 918, 942, 954, 956, 959, 960, 967, 968, 975, 979, 982, 984, 985, 986, 993, 997, 998, 999, 1000, 1002, 1010, 1011, 1018, 1024, 1025, 1030, 1031, 1032, 1037, 1043, 1050, 1056, 1059, 1060, 1062, 1063, 1064, 1067, 1070, 1073, 1175, 1197, 1223, 1274.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 148 disconnected components.
#  There are 68 islands with ids: 17, 39, 50, 74, 106, 202, 451, 540, 580, 621, 704, 743, 775, 949, 1022, 1023, 1137, 1181, 1443, 1560, 2060, 2344, 2419, 2683, 2693, 2786, 2834, 2883, 2923, 2927, 3801, 3871, 3872, 4066, 4070, 4080, 4085, 4277, 4404, 4415, 4425, 4427, 4525, 4526, 4584, 4594, 4603, 4657, 4692, 4697, 4785, 4790, 4861, 4953, 5000, 5093, 5114, 5186, 5247, 5292, 5293, 5365, 5415, 5425, 5427, 5434, 5435, 5441.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 196 disconnected components.
#  There are 88 islands with ids: 149, 160, 185, 232, 313, 332, 355, 539, 540, 546, 547, 554, 556, 606, 607, 618, 621, 633, 637, 648, 659, 662, 677, 714, 758, 759, 760, 782, 808, 831, 832, 873, 916, 930, 948, 964, 985, 1001, 1023, 1024, 1070, 1149, 1151, 1152, 1259, 1275, 1282, 1283, 1314, 1342, 1346, 1378, 1381, 1483, 1485, 1554, 1555, 1556, 1587, 1588, 1601, 1634, 1636, 1679, 1700, 1745, 1760, 1774, 1799, 1817, 1818, 1832, 1837, 1849, 1852, 1875, 1876, 1915, 1936, 1942, 1955, 1961, 1968, 1978, 1986, 2010, 2074, 2075.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 54 disconnected components.
#  There are 24 islands with ids: 0, 1, 2, 136, 486, 869, 1435, 1540, 1668, 1733, 1955, 2343, 2595, 2944, 2964, 3027, 3028, 3054, 3055, 3061, 3076, 3077, 3078, 3079.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 73 disconnected components.
#  There are 43 islands with ids: 2, 3, 7, 24, 25, 26, 27, 31, 46, 50, 51, 52, 53, 54, 63, 72, 73, 76, 79, 92, 107, 114, 115, 119, 120, 123, 128, 132, 135, 140, 141, 142, 143, 160, 163, 175, 176, 182, 185, 195, 202, 229, 230.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There are 3 islands with ids: 0, 2, 5.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 13 disconnected components.
#  There are 9 islands with ids: 0, 1, 8, 12, 13, 14, 23, 24, 25.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 27 disconnected components.
#  There are 18 islands with ids: 0, 1, 2, 3, 4, 10, 1207, 1263, 1286, 1336, 1337, 1341, 1342, 1343, 1344, 1347, 1348, 1349.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 22 disconnected components.
#  There are 11 islands with ids: 0, 1, 4, 5, 17, 27, 28, 32, 33, 34, 38.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 48 disconnected components.
#  There are 26 islands with ids: 1, 13, 14, 49, 121, 127, 133, 151, 176, 257, 258, 295, 387, 388, 571, 638, 1021, 1471, 2091, 2528, 3572, 3609, 3937, 4123, 4124, 4147.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 176 disconnected components.
#  There are 96 islands with ids: 3, 67, 82, 83, 161, 169, 177, 179, 193, 206, 207, 208, 210, 214, 249, 250, 262, 298, 321, 322, 362, 369, 376, 381, 382, 388, 396, 397, 402, 411, 412, 421, 427, 428, 430, 433, 434, 435, 438, 447, 452, 458, 459, 464, 466, 486, 488, 491, 494, 501, 514, 516, 517, 520, 525, 533, 534, 535, 539, 540, 541, 542, 546, 551, 554, 558, 562, 566, 567, 569, 579, 582, 583, 589, 595, 601, 606, 614, 619, 623, 634, 635, 636, 640, 656, 657, 662, 669, 672, 680, 681, 682, 683, 684, 685, 688.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 244 disconnected components.
#  There are 126 islands with ids: 1, 3, 4, 5, 6, 7, 120, 121, 139, 152, 158, 164, 167, 168, 172, 173, 176, 179, 188, 201, 206, 207, 215, 225, 234, 239, 250, 251, 261, 269, 272, 288, 305, 306, 335, 346, 369, 410, 427, 432, 461, 462, 468, 513, 523, 550, 571, 583, 645, 687, 830, 838, 845, 859, 862, 929, 1023, 1030, 1034, 1062, 1102, 1266, 1281, 1306, 1522, 1543, 1935, 1986, 2038, 2093, 2149, 2156, 2247, 2273, 2487, 2525, 2585, 2632, 2644, 2645, 2706, 2835, 2983, 3157, 3158, 3278, 3322, 3401, 3495, 3539, 3581, 3713, 3781, 3837, 3860, 3861, 3862, 3886, 3887, 3888, 3895, 3939, 3940, 3965, 3990, 3991, 4008, 4017, 4128, 4178, 4191, 4237, 4241, 4258, 4433, 4554, 4565, 4578, 4579, 4607, 4609, 4616, 4629, 4632, 4639, 4640.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 421 disconnected components.
#  There are 227 islands with ids: 25, 33, 37, 38, 39, 40, 43, 48, 49, 50, 61, 96, 131, 231, 296, 317, 339, 367, 369, 389, 392, 428, 437, 472, 476, 494, 503, 542, 580, 593, 616, 617, 618, 649, 684, 752, 756, 757, 787, 788, 793, 827, 836, 860, 862, 865, 892, 903, 930, 951, 974, 1022, 1043, 1044, 1046, 1048, 1054, 1077, 1078, 1092, 1104, 1105, 1107, 1110, 1116, 1150, 1153, 1165, 1168, 1232, 1235, 1267, 1268, 1281, 1305, 1306, 1307, 1322, 1323, 1324, 1396, 1417, 1424, 1425, 1450, 1477, 1501, 1515, 1522, 1523, 1547, 1566, 1604, 1606, 1612, 1626, 1653, 1656, 1657, 1666, 1667, 1696, 1697, 1707, 1710, 1722, 1723, 1724, 1726, 1747, 1764, 1765, 1770, 1776, 1778, 1779, 1784, 1790, 1791, 1793, 1801, 1802, 1808, 1812, 1814, 1819, 1823, 1824, 1838, 1864, 1865, 1879, 1893, 1895, 1896, 1902, 1948, 1954, 1968, 1970, 1978, 1982, 1983, 1984, 1992, 1993, 1997, 1998, 2010, 2011, 2047, 2053, 2055, 2069, 2083, 2084, 2100, 2113, 2115, 2144, 2148, 2149, 2166, 2167, 2169, 2174, 2178, 2179, 2185, 2186, 2188, 2191, 2196, 2201, 2202, 2203, 2210, 2237, 2240, 2241, 2250, 2259, 2268, 2275, 2276, 2277, 2289, 2291, 2316, 2320, 2341, 2367, 2383, 2385, 2403, 2407, 2421, 2422, 2565, 2566, 2579, 2596, 2597, 2613, 2621, 2622, 2624, 2631, 2632, 2637, 2649, 2651, 2652, 2655, 2670, 2685, 2686, 2704, 2705, 2710, 2723, 2784, 2852, 2863, 2871, 2878, 2879.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 119 disconnected components.
#  There are 62 islands with ids: 38, 56, 77, 109, 133, 199, 398, 464, 526, 640, 737, 788, 989, 1084, 1194, 1240, 1291, 1293, 1425, 1427, 1506, 1509, 1537, 1735, 1736, 1788, 1856, 1857, 1858, 1935, 2009, 2082, 2087, 2168, 2699, 3069, 3344, 3357, 3390, 3409, 3449, 3477, 3505, 3540, 3580, 3581, 3611, 3634, 3649, 3663, 3680, 3781, 3789, 3797, 3811, 3835, 3860, 3914, 3931, 3932, 3935, 3943.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 159 disconnected components.
#  There are 90 islands with ids: 7, 32, 50, 59, 69, 70, 71, 95, 96, 97, 116, 126, 194, 234, 250, 271, 298, 372, 396, 417, 539, 555, 558, 588, 632, 635, 658, 667, 670, 671, 684, 685, 703, 719, 720, 736, 737, 747, 758, 759, 763, 767, 768, 775, 779, 782, 783, 784, 785, 787, 790, 796, 798, 799, 801, 802, 809, 811, 812, 815, 821, 825, 827, 828, 829, 836, 840, 846, 853, 873, 874, 889, 895, 909, 935, 981, 982, 1032, 1056, 1057, 1073, 1085, 1153, 1243, 1347, 1434, 1523, 1713, 1724, 1732.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 33 disconnected components.
#  There are 21 islands with ids: 5, 6, 8, 18, 66, 85, 176, 609, 649, 685, 722, 810, 856, 944, 989, 1032, 1248, 2213, 2382, 2386, 2389.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 71 disconnected components.
#  There are 45 islands with ids: 1, 6, 9, 10, 13, 17, 19, 32, 33, 39, 40, 53, 57, 58, 60, 63, 109, 110, 116, 125, 126, 127, 130, 135, 136, 137, 142, 160, 162, 165, 166, 174, 175, 176, 184, 185, 186, 187, 188, 189, 190, 191, 192, 199, 200.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 81 disconnected components.
#  There are 40 islands with ids: 70, 99, 213, 214, 262, 456, 457, 589, 1499, 1717, 2626, 2870, 2952, 3106, 3172, 3677, 4316, 4416, 5133, 5360, 5571, 5688, 6308, 6416, 6546, 6672, 6792, 7061, 7280, 7535, 7664, 8081, 8358, 10327, 11364, 13026, 13027, 14818, 16665, 16724.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 657 disconnected components.
#  There are 337 islands with ids: 13, 22, 53, 54, 62, 73, 78, 87, 89, 95, 98, 103, 104, 107, 109, 120, 121, 122, 125, 126, 128, 129, 133, 134, 139, 140, 141, 142, 155, 164, 166, 178, 184, 196, 197, 198, 210, 214, 222, 224, 226, 229, 232, 235, 240, 241, 250, 251, 255, 262, 267, 274, 278, 282, 317, 321, 322, 336, 337, 339, 340, 341, 342, 343, 347, 348, 349, 350, 354, 355, 356, 357, 358, 366, 376, 382, 384, 386, 392, 395, 396, 397, 406, 412, 413, 417, 418, 425, 426, 437, 438, 439, 463, 464, 466, 486, 487, 501, 505, 515, 518, 525, 544, 551, 553, 558, 565, 568, 579, 580, 584, 596, 600, 602, 603, 606, 607, 616, 622, 623, 630, 631, 635, 636, 641, 649, 650, 675, 682, 693, 704, 705, 710, 718, 723, 727, 729, 734, 739, 744, 747, 749, 761, 769, 785, 786, 803, 807, 821, 828, 835, 838, 846, 850, 860, 861, 862, 863, 871, 878, 883, 888, 890, 896, 903, 905, 917, 918, 922, 939, 947, 949, 953, 976, 982, 989, 991, 993, 995, 996, 997, 1009, 1013, 1017, 1018, 1020, 1023, 1028, 1032, 1033, 1035, 1036, 1037, 1038, 1043, 1046, 1056, 1057, 1059, 1075, 1089, 1093, 1103, 1110, 1112, 1117, 1131, 1140, 1145, 1147, 1155, 1157, 1165, 1166, 1169, 1170, 1195, 1213, 1232, 1233, 1242, 1255, 1280, 1284, 1290, 1291, 1310, 1313, 1324, 1325, 1335, 1336, 1337, 1351, 1355, 1368, 1401, 1403, 1422, 1433, 1434, 1441, 1442, 1449, 1452, 1455, 1477, 1484, 1496, 1497, 1510, 1530, 1532, 1533, 1534, 1544, 1554, 1562, 1564, 1578, 1584, 1595, 1597, 1598, 1613, 1616, 1627, 1629, 1630, 1631, 1654, 1662, 1669, 1679, 1686, 1689, 1710, 1725, 1738, 1739, 1744, 1746, 1751, 1752, 1764, 1765, 1775, 1796, 1797, 1802, 1813, 1817, 1823, 1825, 1827, 1832, 1833, 1840, 1841, 1842, 1843, 1856, 1858, 1865, 1872, 1883, 1884, 1893, 1900, 1901, 1918, 1948, 1949, 1956, 1957, 1963, 1965, 1966, 1967, 1971, 1972, 1973, 1982, 2017, 2019, 2033, 2034, 2043, 2044, 2049, 2052, 2061, 2066, 2094, 2101, 2108, 2109.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 10 disconnected components.
#  There are 5 islands with ids: 0, 3, 24, 1759, 1878.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 35 disconnected components.
#  There are 23 islands with ids: 0, 5, 9, 10, 11, 14, 15, 16, 17, 25, 37, 51, 61, 118, 122, 123, 124, 125, 126, 127, 129, 139, 140.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 13 disconnected components.
#  There are 4 islands with ids: 119, 141, 221, 681.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 24 disconnected components.
#  There are 10 islands with ids: 43, 64, 76, 91, 124, 172, 180, 181, 182, 188.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 43 disconnected components.
#  There are 20 islands with ids: 0, 1, 37, 108, 194, 287, 324, 866, 965, 1218, 1440, 1450, 1487, 1549, 1583, 1644, 1925, 2013, 2014, 2015.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 96 disconnected components.
#  There are 47 islands with ids: 9, 10, 11, 12, 14, 15, 19, 20, 26, 42, 45, 49, 54, 55, 70, 74, 77, 80, 83, 87, 131, 138, 154, 155, 175, 180, 183, 184, 185, 190, 191, 192, 195, 199, 201, 207, 230, 245, 280, 292, 310, 316, 321, 334, 339, 349, 350.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 74 disconnected components.
#  There are 21 islands with ids: 14, 21, 46, 206, 273, 343, 390, 415, 449, 493, 562, 797, 938, 1024, 1079, 1432, 2054, 2832, 3119, 3172, 3271.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 182 disconnected components.
#  There are 96 islands with ids: 21, 26, 45, 46, 47, 48, 49, 52, 57, 63, 64, 72, 76, 77, 78, 105, 106, 114, 116, 122, 128, 129, 134, 145, 160, 258, 285, 299, 319, 338, 342, 343, 361, 381, 382, 401, 407, 417, 422, 423, 424, 428, 429, 430, 435, 440, 442, 443, 444, 445, 454, 457, 458, 464, 466, 471, 473, 480, 481, 486, 489, 494, 497, 498, 501, 525, 535, 536, 544, 553, 557, 562, 565, 566, 580, 592, 604, 617, 618, 632, 633, 634, 653, 664, 674, 675, 703, 704, 827, 860, 873, 902, 1002, 1047, 1151, 1173.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 34 disconnected components.
#  There are 12 islands with ids: 0, 8, 9, 10, 113, 156, 686, 783, 888, 2655, 2692, 3146.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 109 disconnected components.
#  There are 59 islands with ids: 14, 30, 31, 32, 37, 38, 41, 54, 70, 71, 72, 73, 74, 75, 81, 113, 127, 131, 138, 139, 143, 145, 146, 149, 150, 152, 153, 158, 159, 160, 161, 163, 169, 181, 184, 185, 192, 193, 194, 200, 201, 204, 205, 206, 214, 215, 216, 221, 222, 227, 233, 239, 255, 256, 257, 261, 266, 283, 287.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 49 disconnected components.
#  There are 20 islands with ids: 12, 125, 219, 229, 609, 653, 807, 1156, 1308, 1311, 1365, 1882, 2008, 2106, 2157, 2195, 2244, 2470, 2529, 2783.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 105 disconnected components.
#  There are 59 islands with ids: 4, 7, 42, 58, 131, 150, 153, 157, 161, 162, 166, 167, 168, 172, 173, 175, 198, 199, 213, 238, 251, 266, 272, 296, 297, 298, 350, 368, 397, 492, 538, 539, 603, 623, 624, 625, 626, 647, 649, 652, 653, 656, 657, 658, 661, 678, 684, 688, 705, 706, 715, 723, 736, 745, 757, 758, 764, 769, 770.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 27 disconnected components.
#  There are 8 islands with ids: 314, 791, 967, 1062, 1446, 1506, 1592, 1595.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 52 disconnected components.
#  There are 32 islands with ids: 68, 76, 81, 82, 83, 85, 86, 90, 91, 92, 97, 101, 105, 116, 117, 131, 173, 221, 222, 238, 251, 258, 259, 268, 272, 279, 287, 296, 309, 310, 311, 325.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 37 disconnected components.
#  There are 16 islands with ids: 137, 175, 207, 237, 263, 339, 654, 687, 688, 1388, 1418, 1703, 1728, 1749, 1768, 1792.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 80 disconnected components.
#  There are 40 islands with ids: 20, 57, 70, 84, 125, 132, 133, 150, 157, 159, 160, 169, 177, 191, 203, 226, 258, 273, 274, 288, 298, 335, 341, 342, 348, 363, 391, 403, 404, 442, 510, 567, 595, 596, 597, 631, 632, 633, 642, 666.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 26 disconnected components.
#  There are 7 islands with ids: 65, 298, 357, 392, 444, 1208, 1246.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 67 disconnected components.
#  There are 34 islands with ids: 44, 51, 72, 82, 119, 127, 135, 148, 149, 150, 151, 164, 182, 183, 198, 227, 238, 244, 245, 251, 253, 273, 275, 276, 281, 282, 283, 316, 352, 370, 371, 392, 426, 435.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 51 disconnected components.
#  There are 21 islands with ids: 6, 7, 167, 200, 240, 251, 886, 924, 989, 1078, 1379, 1402, 1415, 1444, 1483, 1548, 1587, 1591, 1592, 1594, 1597.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 107 disconnected components.
#  There are 54 islands with ids: 5, 6, 28, 29, 35, 36, 41, 44, 89, 97, 109, 124, 127, 128, 129, 179, 202, 206, 207, 208, 210, 219, 220, 226, 231, 232, 235, 236, 242, 244, 245, 247, 250, 251, 252, 253, 254, 255, 256, 264, 265, 274, 281, 282, 301, 310, 312, 342, 354, 382, 419, 601, 627, 648.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 81 disconnected components.
#  There are 40 islands with ids: 0, 10, 11, 12, 13, 17, 34, 54, 98, 230, 251, 288, 310, 425, 426, 444, 547, 1003, 1160, 1431, 1490, 1588, 1635, 1659, 1738, 1739, 1740, 1753, 1786, 1803, 1806, 1808, 1812, 1816, 1817, 1818, 1819, 1820, 1825, 1826.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 115 disconnected components.
#  There are 49 islands with ids: 22, 30, 31, 44, 65, 68, 82, 94, 98, 102, 103, 104, 115, 166, 179, 186, 194, 217, 219, 238, 246, 254, 269, 270, 271, 278, 279, 305, 318, 320, 332, 345, 359, 369, 404, 405, 423, 438, 448, 467, 474, 483, 486, 487, 490, 492, 644, 658, 670.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 53 disconnected components.
#  There are 22 islands with ids: 96, 104, 118, 238, 275, 365, 504, 540, 559, 626, 728, 919, 1336, 1400, 1438, 1646, 1944, 1946, 1947, 1969, 2016, 2036.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 92 disconnected components.
#  There are 35 islands with ids: 0, 5, 17, 19, 34, 37, 168, 169, 171, 187, 213, 257, 278, 326, 328, 376, 399, 418, 437, 479, 500, 539, 572, 632, 677, 700, 783, 821, 823, 869, 872, 896, 907, 925, 935.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 19 disconnected components.
#  There are 4 islands with ids: 1248, 1510, 1609, 1611.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 71 disconnected components.
#  There are 35 islands with ids: 52, 63, 76, 77, 90, 91, 103, 115, 126, 139, 151, 178, 221, 227, 232, 233, 234, 235, 237, 239, 240, 241, 244, 254, 256, 260, 263, 266, 289, 296, 310, 320, 330, 336, 355.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 39 disconnected components.
#  There are 20 islands with ids: 200, 282, 311, 320, 326, 375, 382, 462, 538, 576, 603, 1092, 1259, 1300, 1422, 1435, 1598, 1610, 1611, 1805.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 97 disconnected components.
#  There are 46 islands with ids: 182, 365, 398, 423, 442, 524, 739, 747, 760, 775, 776, 783, 784, 786, 787, 790, 791, 792, 793, 797, 798, 803, 810, 812, 816, 821, 823, 824, 837, 842, 846, 860, 861, 869, 870, 879, 904, 915, 930, 935, 942, 947, 949, 950, 953, 957.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 25 disconnected components.
#  There are 9 islands with ids: 3, 22, 428, 568, 946, 997, 1111, 1403, 1420.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 73 disconnected components.
#  There are 41 islands with ids: 33, 34, 47, 92, 110, 179, 197, 198, 202, 203, 206, 207, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 221, 223, 224, 229, 231, 232, 236, 240, 241, 246, 249, 251, 253, 278, 282, 287, 295, 305, 306.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There is 1 island with id: 282.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 18 disconnected components.
#  There are 12 islands with ids: 0, 1, 2, 5, 8, 15, 17, 18, 21, 31, 34, 36.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 4 islands with ids: 0, 537, 540, 541.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There are 3 islands with ids: 0, 1, 2.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 32 disconnected components.
#  There are 12 islands with ids: 0, 17, 22, 27, 66, 243, 461, 537, 633, 798, 873, 894.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 27 disconnected components.
#  There are 7 islands with ids: 2, 46, 50, 66, 67, 90, 161.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 23 disconnected components.
#  There are 10 islands with ids: 0, 389, 601, 632, 645, 691, 821, 823, 825, 828.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 35 disconnected components.
#  There are 19 islands with ids: 0, 12, 29, 50, 52, 63, 73, 74, 78, 83, 87, 94, 104, 105, 109, 112, 114, 123, 126.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 120 disconnected components.
#  There are 73 islands with ids: 9, 11, 12, 13, 14, 26, 27, 28, 66, 70, 73, 74, 86, 99, 112, 117, 128, 130, 133, 135, 147, 157, 167, 170, 181, 217, 234, 299, 320, 321, 362, 377, 492, 648, 693, 719, 720, 721, 793, 800, 816, 827, 848, 852, 886, 900, 927, 942, 948, 949, 955, 962, 963, 967, 970, 975, 976, 979, 980, 982, 984, 987, 990, 991, 992, 993, 994, 996, 1000, 1001, 1003, 1004, 1005.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 103 disconnected components.
#  There are 43 islands with ids: 0, 3, 26, 27, 50, 58, 72, 119, 126, 174, 187, 195, 201, 232, 255, 262, 279, 281, 286, 289, 291, 298, 318, 319, 322, 342, 344, 395, 399, 400, 414, 451, 461, 504, 505, 537, 540, 547, 560, 561, 571, 587, 593.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 62 disconnected components.
#  There are 29 islands with ids: 0, 1, 19, 21, 70, 80, 91, 92, 93, 99, 103, 104, 105, 123, 124, 136, 154, 176, 188, 195, 244, 688, 762, 768, 786, 897, 938, 939, 940.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 80 disconnected components.
#  There are 35 islands with ids: 32, 131, 254, 266, 273, 276, 277, 301, 304, 311, 316, 321, 345, 346, 348, 350, 351, 352, 367, 368, 369, 371, 375, 382, 383, 384, 385, 386, 387, 390, 393, 397, 401, 402, 435.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 40 disconnected components.
#  There are 18 islands with ids: 0, 108, 130, 177, 1062, 1090, 1136, 1156, 1365, 1366, 1481, 1494, 1554, 1575, 1582, 1593, 1596, 1597.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 93 disconnected components.
#  There are 43 islands with ids: 0, 1, 4, 23, 31, 41, 43, 51, 60, 67, 71, 85, 100, 103, 104, 105, 108, 116, 117, 122, 126, 127, 135, 137, 142, 145, 164, 202, 215, 245, 246, 291, 292, 371, 414, 443, 451, 465, 574, 575, 582, 583, 592.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 96 disconnected components.
#  There are 41 islands with ids: 0, 14, 18, 67, 80, 81, 103, 120, 125, 158, 180, 210, 323, 357, 358, 361, 373, 398, 410, 541, 911, 1090, 1152, 1205, 1206, 1392, 1515, 1528, 1642, 1688, 2597, 2906, 2971, 2979, 3110, 3296, 3332, 3333, 3413, 3414, 3573.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 121 disconnected components.
#  There are 47 islands with ids: 0, 31, 102, 113, 314, 460, 501, 503, 540, 591, 636, 643, 706, 707, 730, 775, 778, 831, 957, 994, 1030, 1062, 1064, 1096, 1230, 1516, 1541, 1565, 1578, 1608, 1622, 1677, 1683, 1691, 1702, 1703, 1716, 1717, 1732, 2103, 2129, 2134, 2136, 2138, 2139, 2144, 2175.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 119 disconnected components.
#  There are 65 islands with ids: 0, 2, 17, 29, 67, 71, 86, 87, 88, 93, 104, 163, 187, 339, 380, 386, 509, 542, 572, 573, 598, 618, 638, 660, 661, 710, 733, 767, 877, 924, 925, 972, 1034, 1080, 1159, 1234, 1240, 1267, 1296, 1298, 1333, 1406, 1544, 1709, 1780, 1853, 2495, 2642, 2727, 2728, 2742, 2789, 2801, 2804, 2805, 2806, 2807, 2813, 2814, 2817, 2818, 2827, 2835, 2836, 2842.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 134 disconnected components.
#  There are 64 islands with ids: 67, 157, 175, 212, 231, 240, 268, 291, 365, 367, 455, 574, 610, 652, 653, 672, 677, 678, 684, 706, 709, 714, 725, 737, 747, 760, 761, 768, 781, 800, 949, 950, 957, 1018, 1021, 1037, 1057, 1058, 1059, 1074, 1090, 1125, 1148, 1161, 1163, 1214, 1289, 1306, 1328, 1331, 1345, 1348, 1377, 1378, 1379, 1457, 1483, 1539, 1595, 1641, 1806, 1818, 1905, 1906.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 92 disconnected components.
#  There are 51 islands with ids: 0, 1, 7, 25, 31, 32, 34, 39, 46, 59, 103, 105, 110, 135, 163, 166, 188, 295, 307, 338, 343, 398, 507, 563, 601, 632, 726, 835, 971, 1135, 1191, 1407, 1467, 2172, 2198, 2383, 2384, 2399, 2430, 2482, 2527, 2528, 2548, 2549, 2579, 2623, 2644, 2702, 2712, 2738, 2740.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 143 disconnected components.
#  There are 59 islands with ids: 21, 71, 114, 115, 149, 226, 237, 278, 291, 384, 421, 439, 442, 498, 499, 505, 536, 554, 555, 581, 583, 584, 602, 620, 644, 667, 681, 686, 729, 755, 787, 788, 799, 808, 819, 843, 844, 855, 857, 870, 879, 888, 889, 890, 914, 920, 926, 947, 995, 997, 998, 1009, 1011, 1061, 1105, 1126, 1248, 1455, 1471.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 117 disconnected components.
#  There are 56 islands with ids: 23, 24, 32, 33, 47, 107, 115, 122, 131, 179, 212, 244, 249, 256, 280, 284, 330, 356, 372, 419, 460, 486, 652, 961, 1004, 1141, 1144, 1304, 1312, 1354, 1467, 1533, 1648, 1754, 1778, 1800, 1801, 1802, 1822, 1828, 1842, 1863, 1864, 1939, 1949, 2000, 2003, 2005, 2006, 2007, 2009, 2010, 2031, 2048, 2049, 2058.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 169 disconnected components.
#  There are 75 islands with ids: 0, 28, 35, 47, 48, 53, 72, 86, 90, 112, 113, 175, 211, 244, 262, 279, 339, 359, 416, 424, 501, 537, 556, 616, 696, 713, 775, 797, 801, 811, 884, 885, 930, 935, 940, 952, 953, 956, 963, 995, 1000, 1011, 1019, 1030, 1045, 1058, 1059, 1148, 1189, 1316, 1328, 1344, 1345, 1354, 1355, 1365, 1382, 1383, 1384, 1445, 1446, 1453, 1513, 1528, 1567, 1662, 1663, 1898, 1965, 1999, 2001, 2032, 2036, 2037, 2042.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 120 disconnected components.
#  There are 60 islands with ids: 0, 47, 65, 66, 69, 75, 76, 77, 78, 98, 99, 229, 239, 245, 268, 277, 308, 337, 398, 419, 420, 501, 776, 777, 820, 926, 980, 1273, 1415, 1459, 1546, 1547, 1811, 1852, 1921, 1922, 1952, 1957, 1983, 1985, 2050, 2115, 2143, 2211, 2315, 2497, 2516, 2565, 2570, 2624, 2663, 2707, 2795, 2839, 3037, 3038, 3165, 3235, 3418, 3438.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 203 disconnected components.
#  There are 77 islands with ids: 24, 42, 43, 45, 48, 51, 89, 96, 109, 181, 202, 240, 369, 385, 405, 469, 485, 518, 568, 573, 592, 606, 608, 638, 655, 661, 683, 685, 785, 791, 831, 838, 849, 850, 851, 873, 874, 911, 937, 1064, 1066, 1072, 1092, 1101, 1123, 1124, 1211, 1290, 1344, 1395, 1411, 1450, 1451, 1510, 1512, 1525, 1586, 1608, 1620, 1639, 1641, 1778, 1794, 1805, 1939, 1964, 1980, 1981, 2006, 2027, 2040, 2041, 2042, 2046, 2057, 2067, 2079.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 51 disconnected components.
#  There are 25 islands with ids: 22, 40, 111, 112, 113, 116, 117, 118, 123, 125, 130, 133, 162, 253, 351, 1640, 1917, 1919, 2524, 2782, 2794, 2804, 2848, 2882, 2893.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 94 disconnected components.
#  There are 44 islands with ids: 115, 290, 304, 325, 363, 467, 681, 696, 706, 721, 741, 758, 767, 782, 786, 793, 794, 795, 798, 802, 803, 804, 805, 806, 808, 811, 824, 825, 831, 834, 836, 849, 854, 880, 886, 888, 890, 891, 892, 895, 918, 921, 935, 960.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 75 disconnected components.
#  There are 40 islands with ids: 23, 135, 266, 278, 294, 325, 383, 504, 535, 557, 564, 571, 594, 630, 671, 773, 800, 830, 856, 939, 965, 966, 989, 990, 1019, 1181, 1187, 1208, 1233, 1305, 1325, 1381, 1402, 1406, 1410, 1512, 1528, 1561, 1565, 1568.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 85 disconnected components.
#  There are 32 islands with ids: 72, 184, 185, 266, 434, 443, 457, 592, 617, 724, 739, 749, 768, 774, 775, 787, 798, 826, 921, 1002, 1040, 1044, 1047, 1055, 1078, 1106, 1125, 1159, 1160, 1169, 1174, 1248.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 151 disconnected components.
#  There are 76 islands with ids: 0, 1, 2, 4, 6, 7, 8, 9, 34, 64, 73, 74, 75, 82, 88, 99, 141, 175, 306, 307, 430, 431, 448, 455, 483, 549, 551, 578, 722, 726, 792, 937, 1300, 1343, 1525, 1536, 1576, 1607, 1658, 1662, 1666, 1685, 1691, 1775, 1777, 1812, 1837, 1954, 2029, 2060, 2065, 2080, 2094, 2095, 2096, 2107, 2132, 2158, 2179, 2246, 2247, 2249, 2293, 2297, 2304, 2309, 2351, 2359, 2377, 2416, 2425, 2426, 2447, 2458, 2483, 2492.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 166 disconnected components.
#  There are 66 islands with ids: 0, 1, 53, 54, 112, 168, 401, 447, 457, 489, 498, 519, 520, 533, 552, 575, 583, 585, 591, 615, 616, 617, 620, 629, 636, 646, 661, 663, 667, 668, 675, 677, 684, 792, 793, 794, 795, 813, 853, 876, 896, 897, 906, 915, 924, 1028, 1072, 1114, 1124, 1156, 1183, 1194, 1195, 1196, 1209, 1322, 1336, 1353, 1364, 1402, 1409, 1437, 1480, 1499, 1526, 1541.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 4 islands with ids: 46, 610, 1062, 1371.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 62 disconnected components.
#  There are 40 islands with ids: 2, 3, 5, 6, 16, 17, 18, 19, 20, 21, 22, 27, 30, 31, 32, 35, 36, 39, 40, 41, 42, 47, 50, 52, 61, 66, 69, 73, 76, 89, 92, 95, 96, 99, 102, 104, 105, 115, 117, 122.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 21 disconnected components.
#  There are 11 islands with ids: 0, 11, 159, 282, 1228, 1673, 1681, 1684, 1686, 1689, 1694.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 90 disconnected components.
#  There are 65 islands with ids: 0, 1, 2, 3, 7, 8, 20, 29, 30, 31, 32, 33, 34, 35, 37, 38, 39, 41, 42, 44, 45, 50, 51, 52, 57, 58, 60, 66, 67, 76, 77, 83, 84, 85, 88, 89, 97, 100, 102, 103, 106, 107, 109, 111, 112, 113, 114, 115, 117, 118, 120, 121, 122, 123, 125, 127, 128, 129, 136, 145, 154, 155, 161, 176, 178.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 35 disconnected components.
#  There are 15 islands with ids: 0, 14, 21, 111, 232, 235, 484, 803, 890, 920, 921, 1026, 1069, 1103, 1104.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 55 disconnected components.
#  There are 21 islands with ids: 86, 87, 94, 102, 127, 143, 167, 186, 198, 209, 245, 247, 248, 249, 267, 272, 304, 314, 320, 325, 333.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 27 disconnected components.
#  There are 17 islands with ids: 9, 237, 856, 857, 858, 931, 950, 951, 972, 973, 998, 1007, 1008, 1037, 1039, 1040, 1087.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 52 disconnected components.
#  There are 25 islands with ids: 0, 1, 6, 7, 10, 12, 13, 15, 19, 24, 27, 28, 29, 32, 42, 43, 51, 97, 155, 160, 168, 209, 211, 212, 252.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 45 disconnected components.
#  There are 28 islands with ids: 0, 2, 11, 51, 60, 80, 103, 139, 275, 283, 316, 361, 403, 442, 443, 485, 667, 693, 720, 805, 980, 986, 1012, 1013, 1021, 1027, 1036, 1043.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 47 disconnected components.
#  There are 24 islands with ids: 56, 65, 90, 106, 142, 143, 177, 239, 302, 319, 320, 351, 355, 359, 367, 373, 378, 382, 385, 387, 402, 424, 440, 447.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 40 disconnected components.
#  There are 23 islands with ids: 0, 5, 6, 14, 89, 152, 211, 283, 311, 333, 361, 377, 378, 385, 393, 394, 410, 755, 787, 810, 821, 825, 882.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 63 disconnected components.
#  There are 25 islands with ids: 0, 27, 39, 41, 45, 52, 53, 54, 64, 73, 75, 103, 116, 124, 128, 136, 147, 162, 235, 268, 350, 360, 387, 409, 464.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 19 disconnected components.
#  There are 11 islands with ids: 0, 1377, 1440, 1617, 1621, 1624, 1626, 1631, 1637, 1638, 1641.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 51 disconnected components.
#  There are 35 islands with ids: 0, 1, 2, 3, 4, 5, 7, 9, 10, 17, 21, 22, 23, 24, 25, 31, 32, 33, 34, 35, 37, 40, 42, 43, 44, 48, 49, 55, 56, 57, 58, 60, 63, 66, 88.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 45 disconnected components.
#  There are 28 islands with ids: 4, 9, 50, 121, 195, 237, 238, 246, 264, 331, 411, 450, 675, 813, 855, 1110, 1147, 1148, 1187, 1266, 1411, 1734, 1776, 1830, 1911, 1947, 1955, 1956.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 70 disconnected components.
#  There are 34 islands with ids: 6, 14, 15, 21, 23, 24, 28, 29, 35, 37, 38, 39, 40, 60, 64, 89, 102, 122, 124, 127, 128, 129, 130, 133, 135, 143, 144, 147, 149, 150, 152, 178, 211, 225.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 47 disconnected components.
#  There are 22 islands with ids: 56, 61, 62, 63, 64, 109, 358, 1004, 1053, 1054, 1102, 1572, 1760, 1988, 2108, 2141, 2252, 2265, 2298, 2716, 3244, 3410.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 126 disconnected components.
#  There are 69 islands with ids: 68, 69, 70, 124, 198, 228, 320, 323, 325, 331, 334, 347, 351, 359, 365, 366, 371, 374, 375, 376, 377, 378, 379, 382, 383, 384, 387, 390, 391, 395, 398, 408, 411, 412, 427, 428, 429, 436, 448, 462, 470, 477, 483, 488, 492, 493, 497, 498, 501, 503, 506, 507, 509, 520, 562, 563, 599, 606, 618, 622, 623, 624, 625, 630, 631, 632, 633, 640, 643.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 35 disconnected components.
#  There are 23 islands with ids: 0, 1, 2, 252, 277, 611, 635, 661, 662, 693, 721, 766, 806, 968, 969, 1263, 1518, 1546, 1580, 1614, 1646, 1741, 1760.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 102 disconnected components.
#  There are 54 islands with ids: 0, 8, 21, 26, 27, 40, 72, 79, 88, 95, 101, 104, 107, 112, 120, 124, 128, 137, 138, 145, 146, 148, 150, 166, 168, 173, 174, 176, 177, 178, 179, 182, 183, 186, 190, 191, 196, 199, 200, 237, 240, 266, 270, 282, 283, 287, 291, 292, 293, 297, 299, 302, 307, 309.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 102 disconnected components.
#  There are 57 islands with ids: 0, 1, 2, 3, 6, 11, 26, 39, 72, 83, 90, 91, 92, 101, 113, 115, 124, 153, 161, 234, 677, 733, 1033, 1482, 1528, 1555, 1556, 1582, 1584, 1616, 1644, 1658, 1668, 1669, 1677, 1679, 1690, 1691, 1709, 1715, 1729, 1738, 1752, 1753, 1759, 1768, 1772, 1787, 1788, 1791, 1823, 1824, 1830, 1834, 1838, 1843, 1856.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 127 disconnected components.
# ...
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There is 1 island with id: 112.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There is 1 island with id: 101.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 14 disconnected components.
#  There are 7 islands with ids: 1, 4, 12, 27, 154, 155, 156.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 11 disconnected components.
#  There are 5 islands with ids: 3, 4, 28, 115, 192.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 8 disconnected components.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 17 disconnected components.
#  There are 11 islands with ids: 0, 1, 34, 110, 112, 129, 130, 131, 189, 191, 197.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 15 disconnected components.
#  There are 2 islands with ids: 10, 272.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 8 disconnected components.
#  There are 3 islands with ids: 0, 194, 195.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 7 disconnected components.
#  There is 1 island with id: 210.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 30 disconnected components.
#  There are 16 islands with ids: 7, 9, 13, 21, 22, 27, 30, 34, 40, 80, 81, 91, 98, 111, 127, 185.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 13 disconnected components.
#  There are 4 islands with ids: 2, 283, 381, 430.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 9 disconnected components.
#  There are 4 islands with ids: 0, 83, 84, 85.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 7 disconnected components.
#  There are 4 islands with ids: 2, 31, 95, 97.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 0.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 2 islands with ids: 0, 1.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 9 disconnected components.
#  There are 2 islands with ids: 77, 85.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There is 1 island with id: 147.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 2 islands with ids: 1, 4.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 9 disconnected components.
#  There are 4 islands with ids: 17, 90, 152, 153.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 8 disconnected components.
#  There are 2 islands with ids: 76, 151.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 3 islands with ids: 0, 3, 113.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There is 1 island with id: 2.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 9 disconnected components.
#  There are 3 islands with ids: 4, 97, 180.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 15 disconnected components.
#  There are 11 islands with ids: 0, 3, 6, 12, 13, 14, 105, 150, 163, 174, 178.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There are 2 islands with ids: 4, 243.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 15 disconnected components.
#  There are 12 islands with ids: 0, 1, 2, 3, 11, 16, 53, 76, 111, 112, 113, 114.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 18 disconnected components.
#  There are 6 islands with ids: 5, 31, 204, 205, 238, 249.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 3 islands with ids: 72, 84, 124.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 9 disconnected components.
#  There are 7 islands with ids: 0, 1, 3, 4, 29, 61, 92.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 15 disconnected components.
#  There are 9 islands with ids: 5, 6, 7, 10, 11, 12, 25, 26, 113.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There is 1 island with id: 138.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There are 3 islands with ids: 0, 111, 112.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 2 islands with ids: 4, 8.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 12 disconnected components.
#  There are 8 islands with ids: 0, 11, 16, 89, 90, 106, 120, 132.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 17 disconnected components.
#  There are 13 islands with ids: 0, 1, 2, 3, 4, 14, 18, 28, 33, 36, 37, 38, 39.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 11 disconnected components.
#  There are 3 islands with ids: 0, 49, 302.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There are 4 islands with ids: 126, 181, 188, 189.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 14 disconnected components.
#  There are 8 islands with ids: 0, 1, 5, 54, 63, 64, 65, 66.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 2 islands with ids: 50, 188.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 11 disconnected components.
#  There are 6 islands with ids: 55, 60, 62, 63, 64, 65.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There are 4 islands with ids: 34, 56, 214, 218.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 3 islands with ids: 0, 1, 2.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 18 disconnected components.
#  There are 6 islands with ids: 44, 77, 113, 145, 199, 219.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 4 islands with ids: 0, 26, 35, 130.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There is 1 island with id: 242.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 7 disconnected components.
#  There are 4 islands with ids: 0, 14, 18, 19.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There are 2 islands with ids: 0, 1.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There are 2 islands with ids: 0, 1.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 7 disconnected components.
#  There are 5 islands with ids: 0, 181, 223, 225, 226.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 16 disconnected components.
#  There are 8 islands with ids: 0, 5, 7, 21, 44, 109, 145, 211.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#  There are 6 islands with ids: 0, 1, 2, 3, 4, 5.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 14 disconnected components.
#  There are 7 islands with ids: 17, 215, 281, 375, 385, 403, 428.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There are 3 islands with ids: 0, 3, 4.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 12 disconnected components.
#  There are 5 islands with ids: 44, 126, 127, 223, 227.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There is 1 island with id: 2.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There are 2 islands with ids: 0, 6.
#   warnings.warn(message)
# C:\Users\fmontana\AppData\Roaming\Python\Python39\site-packages\libpysal\weights\weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There is 1 island with id: 7.
#   warnings.warn(message)

# %% [markdown]
# ### Mid-rise development

# %%
"""
Calculate the Mid-rise development indicator for each city at 250m resolution and city level
Columns of df_lcz:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing low to mid-rise entries.
"""
df = pd.read_csv(f'DATA/data\df_lcz.csv')

for cluster in clusters:

    # Filter by cluster
    df_lcz = df[df.cluster == cluster]

    # Grid cell level
    # Scale to new range 0-10
    df1 = df_lcz.copy()
    MAX = df1['val_grid'].max()
    MIN = df1['val_grid'].min()
    df1['rescaled_grid'] = df1['val_grid'].apply(lambda x: (((x - MIN)/(MAX - MIN))*10))
    df1 = df1[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    # Save data
    df1.to_csv(f'DATA/new_data\\{cluster}\\grid\\Urban Design_Mid-rise development.csv', index=False)

    #City level
    df2 = df_lcz.copy()
    # Calculate the population weighted average of the values for each city
    df2 = (df2.groupby('urau_code').apply(lambda x: (x['pop_final'] * x['val_grid']).sum()) / 
               df2.groupby('urau_code')['pop_final'].sum()).reset_index(name='val_city').merge(df2, on='urau_code', how='inner')
    # Take the city just once
    #df2['val_city'] =df2.groupby('urau_code')['val_grid'].transform('mean')
    df2.drop_duplicates(subset=['urau_code'], inplace=True)

    MAX = df2['val_city'].max()
    MIN = df2['val_city'].min()
    # Scale to new range 0-10
    df2['rescaled_city'] = df2['val_city'].apply(lambda x: (((x -MIN)/(MAX - MIN))*10))
    # Select columns
    df2 = df2[['gid','urau_code','urau_name', 'pop_final', 'val_city', 'rescaled_city','cluster']]
    # Save data
    df2.to_csv(f'DATA/new_data\\{cluster}\\city\\Urban Design_Mid-rise development.csv', index=False)

# %% [markdown]
# ### Permeability

# %%
"""
Calculate the Permeability indicator for each city at 250m resolution and city level
Columns of df_imd:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing percentage of permeability data.
"""
df = pd.read_csv(f'DATA/data/df_imd.csv')
# Set the thresholds for rescaling
threshold = 25
# Set the new target value in the scale [0-10]
new_target = 6

for cluster in clusters:
    df_imd = df[df.cluster == cluster]
    # Grids
    # If values higher than threshold rescaled in [10-6], otherwise [5-0]
    df1 = df_imd.copy()
    MIN = df1['val_grid'].min()
    MAX = df1['val_grid'].max()
    # Apply interpolation for each range
    df['rescaled_grid'] = np.interp(
        df['val_grid'],
        [MIN, threshold, MAX],
        [0, 6, 10],
    )
    # Save data
    df.to_csv(f'DATA/new_data\\{cluster}\\grid\\Urban Design_Permeability.csv', index=False)

    # City
    df2 = df_imd.copy()
    df2['target'] = 0  # Initialize the column with default value 0
    df2.loc[df2['val_grid'] > 25, 'target'] = 1
    df2 = df2.copy()
    # Calculate the percentage of people meeting the grid permeability threshold
    df2['pop_target'] = df2['pop_final']*df2['target']
    df2['pop_sum_when_target_1'] = df2.groupby('urau_code')['pop_target'].transform('sum')
    df2['sum_pop'] = df2.groupby('urau_code')['pop_final'].transform('sum')
    df2['val_city'] = df2['pop_sum_when_target_1']/df2['sum_pop']*100
    # Rescale the values to the range [0-10]
    df2['rescaled_city'] = df2['val_city']/10 
    # Take the city just once
    df2 = df2.drop_duplicates('urau_name')
    df2 = df2[['gid','urau_code','urau_name', 'pop_final', 'val_city','rescaled_city','cluster']]

    df2.to_csv(f'DATA/new_data\\{cluster}\\city\\Urban Design_Permeability.csv', index=False)

# %% [markdown]
# # Sustainable Transportation

# %% [markdown]
# ###  Opportunity to walk

# %%
"""
Calculate the Opportunity to walk indicator for each city at 250m resolution and city level
Columns of df_walk:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing % pedestrian infrastructure.
"""
df = pd.read_csv(f'DATA/data/df_walk.csv')
MIN_all = 0
MAX_all = 70
for cluster in clusters:

    df_ped = df[df.cluster == cluster]

    # Define the threshold for rescaling
    MAX = df_ped['val_grid'].max()
    MIN = df_ped['val_grid'].min()
    # Grid cell level
    
    # Apply rescaling directly without a function
    df_ped = df_ped.copy()
    df_ped['rescaled_grid'] = df_ped['val_grid'].apply(lambda x: 10 if x > MAX else (np.sqrt(x) / np.sqrt(MAX)) * 10)
                                                       #(((x -MIN)/(MAX - MIN))*10))
                                                       # lambda x: 10 if x > MAX else (np.sqrt(x) / np.sqrt(MAX)) * 10)
    df_ped = df_ped[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    # Save data
    df_ped.to_csv(f'DATA/new_data\\{cluster}\\grid\\Sustainable Transportation_Opportunity to walk.csv', index=False)

    #City -- POPULATION WEIGHTED OPTIONS 
    df_ped2 = (df_ped.groupby('urau_code').apply(lambda x: (x['pop_final'] * x['val_grid']).sum()) / 
               df_ped.groupby('urau_code')['pop_final'].sum()).reset_index(name='val_city').merge(df_ped, 
                                                                                                          on='urau_code', how='inner')

    df_ped2 = df_ped2.drop_duplicates(subset=['urau_code'])
    df_ped2 = df_ped2.copy()
    df_ped2['rescaled_city'] = df_ped2['val_city'].apply(
        lambda x: 10 if x > MAX_all else (np.sqrt(x) / np.sqrt(MAX_all)) * 10)    
    #MIN = df_ped2['val_city'].min()
    #MAX = df_ped2['val_city'].max()
    #df_ped2['rescaled_city'] = df_ped2['val_city'].apply(lambda x: (np.sqrt(x) / np.sqrt(MAX)) * 10)
    df_ped2 = df_ped2[['gid','urau_code','urau_name', 'pop_final', 'val_city', 'rescaled_city','cluster']]
    df_ped2.to_csv(f'DATA/new_data\\{cluster}\\city\Sustainable Transportation_Opportunity to walk.csv', index=False)

# %% [markdown]
# ### Opportunity to cycle

# %%
"""
Calculate the Opportunity to cycle indicator for each city at 250m resolution and city level
Columns of df_cycl:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing % cycling infrastructure.
"""
df = pd.read_csv(f'DATA/data/df_cycl.csv')
MIN_all = 0
MAX_all = 35
for cluster in clusters:

    df_cycl = df[df.cluster == cluster]

    # Define the threshold for rescaling
    MAX = df_cycl['val_grid'].max()
    MIN = df_cycl['val_grid'].min()

    # Grid cell level
    # Apply rescaling directly without a function
    df_cycl = df_cycl.copy()
    #df_cycl['rescaled_grid'] = df_cycl['val_grid'].apply(lambda x: (((x -MIN)/(MAX - MIN))*10))
    df_cycl['rescaled_grid'] = df_cycl['val_grid'].apply(
        lambda x: 10 if x > MAX else (np.sqrt(x) / np.sqrt(MAX)) * 10)
    df_cycl = df_cycl[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    # Save data
    df_cycl.to_csv(f'DATA/new_data\\{cluster}\\grid\\Sustainable Transportation_Opportunity to cycle.csv', index=False)

    #City -- POPULATION WEIGHTED OPTIONS 
    df_cycl2 = (df_cycl.groupby('urau_code').apply(lambda x: (x['pop_final'] * x['val_grid']).sum()) / 
               df_cycl.groupby('urau_code')['pop_final'].sum()).reset_index(name='val_city').merge(df_cycl, 
                                                                                                          on='urau_code', how='inner')

    df_cycl2 = df_cycl2.drop_duplicates(subset=['urau_code'])
    df_cycl2 = df_cycl2.copy()
    df_cycl2['rescaled_city'] = df_cycl2['val_city'].apply(
        lambda x: 10 if x > MAX else (np.sqrt(x) / np.sqrt(MAX_all)) * 10)    
    #MIN = df_cycl2['val_city'].min()
    #MAX = df_cycl2['val_city'].max()
    #df_cycl2['rescaled_city'] = df_cycl2['val_city'].apply(lambda x: (np.sqrt(x) / np.sqrt(MAX)) * 10)  
    df_cycl2 = df_cycl2[['gid','urau_code','urau_name', 'pop_final', 'val_city', 'rescaled_city','cluster']]
    df_cycl2.to_csv(f'DATA/new_data\\{cluster}\\city\Sustainable Transportation_Opportunity to cycle.csv', index=False)

# %% [markdown]
# ### Public transport stops

# %%
"""
Calculate the Public transport stops indicator for each city at 250m resolution and city level
Columns of df_pubtrans:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing # of public transport stops.
"""
df = pd.read_csv(f'DATA/data/df_pubtrans.csv')
for cluster in clusters:
    df_bus = df[df.cluster == cluster]

    #Grid cell level
    df_bus = df_bus.copy()
    MIN = 0
    MAX = 20
    # Rescale such as 0 is 0 and 20 is 10
    df_bus['rescaled_grid'] = df_bus['val_grid'].apply(
        lambda x: 10 if x > MAX else (np.sqrt(x) / np.sqrt(MAX)) * 10
    )
    df_bus = df_bus[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    df_bus.to_csv(f'DATA/new_data\\{cluster}\\grid\\Sustainable Transportation_Public transport stops.csv', index=False)

    #City  
    df_bus2 = df_bus.copy()
    df_bus2['present'] = 0  # Initialize the column with default value 0
    df_bus2.loc[df_bus2['val_grid'] > 0, 'present'] = 1  # Set value to 1 where val_grid > 0
    df_bus2['bus_tot_city'] = df_bus2.groupby('urau_code')['present'].transform('sum')
    df_bus2['grids'] = df_bus2.groupby('urau_code')['urau_name'].transform('size') 
    df_bus2 = df_bus2.drop_duplicates(subset=['urau_code'])
    df_bus2['bus_perc_city'] = df_bus2['bus_tot_city']/df_bus2['grids']*100
    df_bus2['rescaled_city'] = df_bus2['bus_perc_city']/10
    df_bus2 = df_bus2.drop_duplicates(subset=['urau_code'])
    df_bus2.rename(columns={'bus_perc_city': 'val_city'}, inplace=True)

    df_bus2 = df_bus2[['gid','urau_code','urau_name', 'pop_final', 'val_city','rescaled_city','cluster']]
    df_bus2.to_csv(f'DATA/new_data\\{cluster}\\city\Sustainable Transportation_Public transport stops.csv', index=False)

# %% [markdown]
# # Environmental Quality

# %% [markdown]
# ### Air quality (PM2.5)

# %%
"""
Calculate the Air quality (PM2.5) indicator for each city at 250m resolution and city level
Columns of df_pm:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing PM2.5 values.
"""
df = pd.read_csv(f'DATA/data/df_pm.csv')
for cluster in clusters:
    
    df_ap = df[df.cluster == cluster]

    # Grid cell level
    MIN = 5 # this corespond to 10 in the rescaled grid
    MAX = df_ap['val_grid'].max() #corespond to 0 in the rescaled grid

    df_ap = df_ap.copy()

    df_ap['rescaled_grid'] = df_ap['val_grid'].apply(
        lambda x: 10 if x <= MIN else (0 if x >= MAX else 10 * (MAX - x) / (MAX - MIN))
    )
    df_ap.to_csv(f'DATA/new_data\\{cluster}\\grid\\Environmental Quality_Air quality (PM2.5).csv', index=False)

    #City level
    df_ap2 = df_ap.copy()

    # Aggregation
    df_ap2 = (df_ap.groupby('urau_code').apply(lambda x: (x['pop_final'] * x['val_grid']).sum()) / 
              df_ap.groupby('urau_code')['pop_final'].sum()).reset_index(name='val_city').merge(
                  df_ap, on='urau_code', how='inner')
      
    df_ap2 = df_ap2.drop_duplicates(subset=['urau_code'])

    MAX = df_ap2['val_city'].max()

    df_ap2 = df_ap2.copy()
    df_ap2['rescaled_city'] = df_ap2['val_city'].apply(
        lambda x: 10 if x <= MIN else (0 if x >= MAX else 10 * (MAX - x) / (MAX - MIN))
    )
    # Select columns
    df_ap2 = df_ap2[['gid','urau_code','urau_name', 'pop_final', 'val_city','rescaled_city','cluster']] 
    # Save 
    df_ap2.to_csv(f'DATA/new_data\\{cluster}\\city\\Environmental Quality_Air quality (PM2.5).csv', index=False)

# %% [markdown]
# ### Air quality (NO2)

# %%
"""
Calculate the Air quality (NO2) for each city at 250m resolution and city level
Columns of df_no2:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing NO2 values.
"""
df = pd.read_csv(f'DATA/data/df_no2.csv')
for cluster in clusters:
    
    df_ap = df[df.cluster == cluster]

    # Grid cell level
    MIN = 10 # this corespond to 10 in the rescaled grid
    MAX = df_ap['val_grid'].max() #corespond to 0 in the rescaled grid

    df_ap = df_ap.copy()

    df_ap['rescaled_grid'] = df_ap['val_grid'].apply(
        lambda x: 10 if x <= MIN else (0 if x >= MAX else 10 * (MAX - x) / (MAX - MIN))
    )
    df_ap.to_csv(f'DATA/new_data\\{cluster}\\grid\\Environmental Quality_Air quality (NO2).csv', index=False)

    #City level
    df_ap2 = df_ap.copy()

    # Aggregation
    df_ap2 = (df_ap.groupby('urau_code').apply(lambda x: (x['pop_final'] * x['val_grid']).sum()) / 
              df_ap.groupby('urau_code')['pop_final'].sum()).reset_index(name='val_city').merge(
                  df_ap, on='urau_code', how='inner')
      
    df_ap2 = df_ap2.drop_duplicates(subset=['urau_code'])

    MAX = df_ap2['val_city'].max()

    df_ap2 = df_ap2.copy()
    df_ap2['rescaled_city'] = df_ap2['val_city'].apply(
        lambda x: 10 if x <= MIN else (0 if x >= MAX else 10 * (MAX - x) / (MAX - MIN))
    )
    # Select columns
    df_ap2 = df_ap2[['gid','urau_code','urau_name', 'pop_final', 'val_city','rescaled_city','cluster']] 
    # Save 
    df_ap2.to_csv(f'DATA/new_data\\{cluster}\\city\\Environmental Quality_Air quality (NO2).csv', index=False)

# %% [markdown]
# ### Surrounding greenness (NDVI)

# %%
"""
Calculate the Surrounding greenness (NDVI) indicator for each city at 250m resolution and city level
Columns of df_ndvi:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing ndvi values.
"""
df = pd.read_csv(f'DATA/data/df_ndvi.csv')
df_target = pd.read_csv('DATA\\data\df_ndvi_target_tabla.csv')
MAX = 1
MIN = 0
for cluster in clusters:
    df_ndvi = df[df.cluster == cluster]
    
    # Grid
    # Grid
    df_ndvi = pd.merge(df_ndvi, df_target, on = 'urau_code') # Assuming target is the same for all rows in the group
    # Apply rescaling for each urau_code
    # Apply interpolation for each range
    df_ndvi['rescaled_grid'] = np.interp(
        df_ndvi['val_grid'],
        [MIN, threshold, MAX],
        [0, 6, 10],
    )
    df_ndvi2 = df_ndvi[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    df_ndvi2.to_csv(f'DATA/new_data\\{cluster}\\grid\\Environmental Quality_Surrounding greenness.csv', index=False)

    # City
    df_ndvi2 = df_ndvi.copy()
    df_ndvi2['target'] = 0  # Initialize the column with default value 0
    # Set value to 1 where val_grid > target_ndvi
    df_ndvi2.loc[df_ndvi2['val_grid'] >= df_ndvi2['target_ndvi'], 'target'] = 1
    # Calculate the percentage of people meeting the grid NDVI threshold
    df_ndvi2['pop_target'] = df_ndvi2['pop_final']*df_ndvi2['target']
    df_ndvi2['pop_sum_when_target_1'] = df_ndvi2.groupby('urau_code')['pop_target'].transform('sum')
    df_ndvi2['sum_pop'] = df_ndvi2.groupby('urau_code')['pop_final'].transform('sum')
    df_ndvi2['val_city'] = df_ndvi2['pop_sum_when_target_1']/df_ndvi2['sum_pop']*100
    # Rescale the values to the range [0-10]
    df_ndvi2['rescaled_city'] = df_ndvi2['val_city']/10
    df_ndvi2 = df_ndvi2.drop_duplicates(subset=['urau_code'])
    # Select columns
    df_ndvi2 = df_ndvi2[['gid','urau_code','urau_name', 'pop_final', 'val_city', 'rescaled_city','cluster']]
    # Save 
    df_ndvi2.to_csv(f'DATA/new_data\\{cluster}\\city\\Environmental Quality_Surrounding greenness.csv', index=False)

# %% [markdown]
# ### Lower Urban Heat Islands (UHI)

# %%
"""
Calculate the Lower Urban Heat Islands (UHI) indicator for each city at 250m resolution and city level
Columns of df_uhi:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing uhi values.
"""
df = pd.read_csv(f'DATA/data/df_uhi.csv')
for cluster in clusters:

    df_uhi = df[df.cluster == cluster]  

    # Grids
    MIN = df_uhi.val_grid.min()
    MAX = df_uhi.val_grid.max()
    
    df_uhi['rescaled_grid'] = df_uhi['val_grid'].apply(lambda x: 10-(((x - MIN)/( MAX - MIN))*10))
    df_uhi.to_csv(f'DATA/new_data\\{cluster}\\grid\\Environmental Quality_Lower urban heat islands.csv', index=False)

    #City
    df_uhi2 = (df_uhi.groupby('urau_code').apply(lambda x: (x['pop_final'] * x['val_grid']).sum()) / 
               df_uhi.groupby('urau_code')['pop_final'].sum()).reset_index(name='val_city')
    df_uhi2 = pd.merge(df_uhi2,df_uhi, on='urau_code', how='inner')
    df_uhi2 = df_uhi2.drop_duplicates(subset=['urau_code'])

    MAX = df_uhi2.val_city.max()
    MIN = df_uhi2.val_city.min()

    df_uhi2 = df_uhi2.copy()

    df_uhi2['rescaled_city'] = df_uhi2['val_city'].apply(
        lambda x: ((MAX-x)/(MAX - MIN))*10)
    # Select columns
    df_uhi2 = df_uhi2[['gid','urau_code','urau_name', 'pop_final', 'val_city', 'rescaled_city','cluster']]
    df_uhi2.to_csv(f'DATA/new_data\\{cluster}\\city\Environmental Quality_Lower urban heat islands.csv', index=False)
# Out:
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\1155148064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uhi['rescaled_grid'] = df_uhi['val_grid'].apply(lambda x: 10-(((x - MIN)/( MAX - MIN))*10))
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\1155148064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uhi['rescaled_grid'] = df_uhi['val_grid'].apply(lambda x: 10-(((x - MIN)/( MAX - MIN))*10))
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\1155148064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uhi['rescaled_grid'] = df_uhi['val_grid'].apply(lambda x: 10-(((x - MIN)/( MAX - MIN))*10))
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\1155148064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uhi['rescaled_grid'] = df_uhi['val_grid'].apply(lambda x: 10-(((x - MIN)/( MAX - MIN))*10))
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_21796\1155148064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uhi['rescaled_grid'] = df_uhi['val_grid'].apply(lambda x: 10-(((x - MIN)/( MAX - MIN))*10))

# %% [markdown]
# ## Green Accessibility

# %% [markdown]
# ### Universal Access to Green Spaces

# %%
"""
Calculate the Universal Access to Green Spaces indicator for each city at 250m resolution and city level
Columns of df_300m:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing log values of accessibility to green spaces.
- target_pop: Numeric values containing the target population.
"""
df = pd.read_csv(f'DATA\\data\\df_300m.csv')
# Read geodataframe
gdf = gpd.read_file(f'DATA/data/gdf_pop.geojson')
gdf1 = gdf.copy()
for cluster in clusters:

    df1 = df[df.cluster == cluster]

    # Rescale to a range from 0 to 10
    MIN = df1['val_grid'].min()
    MAX = df1['val_grid'].max()

    # Grid
    df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
    df1 = pd.merge(df1, gdf1[['gid','urau_code','pop_final','geometry']], on = ['gid','urau_code'], how = 'inner')
    # df3.loc[df3['urau_name'].str.contains(r'Bucure\?ti', regex=True), 'urau_name'] = 'Bucuresti'
    # df3.loc[df3['urau_name'].str.contains(r'Bucure?ti', regex=True), 'urau_name'] = 'Bucuresti'
    df2 = df1[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    df2.to_csv(f'DATA/new_data\\{cluster}\\grid\\Green Spaces Accessibility_Universal access to green spaces.csv', index=False)

    #City
    df3 = df1.copy()
    df3['target_pop_sum'] = df3.groupby('urau_code')['target_pop'].transform('sum')
    df3['sum_pop'] = df3.groupby('urau_code')['pop_final'].transform('sum')
    df3['val_city'] = (df3['target_pop_sum']/df3['sum_pop'])*100
    df3 = df3.drop_duplicates(subset=['urau_code'])
    MIN = 0
    MAX = 100
    df3 = df3.copy()
    df3['rescaled_city'] = df3['val_city'].apply(lambda x: (((x - MIN)/(MAX - MIN))*10))
    df3 = df3[['gid','urau_code','urau_name', 'pop_final', 'val_city','rescaled_city','cluster']]


    df3.to_csv(f'DATA/new_data\\{cluster}\\city\Green Spaces Accessibility_Universal access to green spaces.csv', index=False)
# Out:
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\3617827850.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\3617827850.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\3617827850.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\3617827850.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\3617827850.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)

# %% [markdown]
# ### Access to Large Green Spaces

# %%
"""
Calculate the Access to Large Green Spaces indicator for each city at 250m resolution and city level
Columns of df_2km:
- gid: Unique identifier for each row.
- pop_final: Population count.
- urau_code: Unique identifier for each urban area.
- urau_name: Name of the urban area.
- cluster: Cluster to which the urban area belongs.
- val_grid: Numeric values containing log values of accessibility to green spaces.
- target_pop: Numeric values containing the target population.
"""
df = pd.read_csv(f'DATA\\data\\df_2km.csv')
# Read geodataframe
# gdf1 = gpd.read_file(f'DATA/data/gdf_pop.geojson')
for cluster in clusters:

    df1 = df[df.cluster == cluster]

    # Rescale to a range from 0 to 10
    MIN = df1['val_grid'].min()
    MAX = df1['val_grid'].max()

    # Grid
    df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
    df1 = pd.merge(df1, gdf1[['gid','urau_code','pop_final','geometry']], on = ['gid','urau_code'], how = 'inner')
    # df3.loc[df3['urau_name'].str.contains(r'Bucure\?ti', regex=True), 'urau_name'] = 'Bucuresti'
    # df3.loc[df3['urau_name'].str.contains(r'Bucure?ti', regex=True), 'urau_name'] = 'Bucuresti'
    df2 = df1[['gid', 'urau_code','urau_name','pop_final', 'val_grid', 'rescaled_grid','cluster']]
    df2.to_csv(f'DATA/new_data\\{cluster}\\grid\\Green Spaces Accessibility_Access to large green spaces.csv', index=False)

    #City
    df3 = df1.copy()
    df3['target_pop_sum'] = df3.groupby('urau_code')['target_pop'].transform('sum')
    df3['sum_pop'] = df3.groupby('urau_code')['pop_final'].transform('sum')
    df3['val_city'] = (df3['target_pop_sum']/df3['sum_pop'])*100
    df3 = df3.drop_duplicates(subset=['urau_code'])
    MIN = 0
    MAX = 100
    df3 = df3.copy()
    df3['rescaled_city'] = df3['val_city'].apply(lambda x: (((x - MIN)/(MAX - MIN))*10))
    df3 = df3[['gid','urau_code','urau_name', 'pop_final', 'val_city','rescaled_city','cluster']]


    df3.to_csv(f'DATA/new_data\\{cluster}\\city\Green Spaces Accessibility_Access to large green spaces.csv', index=False)
# Out:
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\476383066.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\476383066.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\476383066.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\476383066.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
# C:\Users\fmontana\AppData\Local\Temp\ipykernel_27284\476383066.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rescaled_grid'] = 10 * (df1['val_grid'] - MIN) / (MAX - MIN)
